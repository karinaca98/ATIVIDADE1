# %% [markdown]
# <a href="https://colab.research.google.com/github/karinaca98/ATIVIDADE1/blob/main/karina_almeida_atividade_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  <center>
#
#  ## **Karina Costa de Almeida**
#
# ![fotokarina.jpg](data:image/jpeg;base64,...)
#
# </center>
#
# ## Perfil
#
# * 24 anos
# * Carioca - Nascida e criada na zona norte da cidade
# * Flamenguista de Coração
#
#   ![flamengo](https://upload.wikimedia.org/wikipedia/commons/f/f1/Kit_body_flamengo2223t_la.png "logo flamengo")
#
# * Adora um churrasco e um pagode
#
# <p align="center">
#   <a href="https://youtu.be/MbLirwiFe9I?list=PLj6s80N1H0lRWZTFes0-lK_bP6Dp-xNUo
# " target="_blank"><img src="https://i.ytimg.com/vi/MbLirwiFe9I/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLClu7Kr5dlWi-KJK1J-mluifQOHIw"
# alt="IMAGE ALT TEXT HERE" width="260" height="200" border="2" /></a>
# </p>
#
#
# * Academicamente tenho muito interesse nas geociências, com foco em sensoriamento remoto e geomorfologia costeira
#
# <p align="center">
#   <a href="https://www.youtube.com/live/ISLtvKHFHCw?feature=share
#   " target="_blank"><img src="https://i.ytimg.com/vi/Q3YPL4f2wfw/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBj5RLHi3ji_KZPrpXjuUId7tqPFw"
# alt="IMAGE ALT TEXT HERE" width="260" height="200" border="2" /></a>
# </p>

# %% [markdown]
# ---
#
#
#
# ## Experiência Acadêmica e Profissional
#
# - 01/2023 - Atual Mestranda do Programa de Pós-graduação Dinâmica dos Oceanos e da Terra [(DOT)](https://dot.uff.br/)
#     - O projeto de mestrado tem como objetivo analisar a dinâmica da linha de costa dos deltas da costa lesta brasileira nas ultimas décadas através da detecção automática da cobertura da terra.
#
# - 03/2022 - Atual Estagiária no Instituto Estadual do Ambiente  [(INEA)](http://www.inea.rj.gov.br/)
#    - O estágio é desenvolvido na Gerência de Gestão do Território e Informações geoespacias, tendo foco em Geoprocessamento.
#
# - 03/2017 - Atual Licenciatura em Geografia na Universidade Federal Fluminense  [(UFF)](https://www.uff.br/)
#
# - 03/2017 - 02/2022 Bacharelado em Geografia na Universidade Federal Fluminense  [(UFF)](https://www.uff.br/)
#
# - 08/2020 - 09/2022 Iniciação Científica - [FAPERJ](https://www.faperj.br/)
#    - Projeto intitulado: Utilização de Google Earth Engine no mapeamento da dinâmica de Spits no delta do rio Paraíba do Sul
#
# Para mais informações: [Lattes](http://lattes.cnpq.br/0550623826256651)
